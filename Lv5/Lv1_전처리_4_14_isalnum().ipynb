# %% [markdown]
# <a href="https://colab.research.google.com/github/uvictoli/Machine_Learning/blob/main/Lv5/Lv1_%EC%A0%84%EC%B2%98%EB%A6%AC_4_14_isalnum().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [↩️ 리스트로 돌아가기](https://dacon.io/competitions/open/235698/overview/description)

# %% [markdown]
# # 셀을 실행할 때 팝업이 뜨면 `무시하고 계속하기` 를 눌러주세요

# %% [markdown]
# ## 실습
# ---

# %%
# isalnum 메소드를 이용해 output에 해당하는 값이 출력 되도록 특정 문자열을 제거 해보세요.

string="year : 2021, month : 09, day : 24"

isalnum_list = []

for c in string:
  if c.isalnum(): isalnum_list.append(c)

string_isalnum = ''.join(isalnum_list)
print(string_isalnum)

# output : year2021month09day24
# Out:
# year2021month09day24

# %% [markdown]
# ## 정답
# ---
# 스스로 실습 코드를 작성 한 후 정답 코드를 확인해 보세요.

# %%
# isalnum 메소드를 이용해 output에 해당하는 값이 출력 되도록 특정 문자열을 제거 해보세요.

string="year : 2021, month : 09, day : 24"

# output : year2021month09day24

#isalnum를 이용해 알파벳값만 담을 리스트
isalnum_list = []

for c in string:
  #isalnum()를 이용해 알파벳값인지 판별
    if c.isalnum():
      isalnum_list.append(c)

#join()메소드를 이용해 알파벳값 만 담긴 리스트를 결합
string_isalnum = ''.join(isalnum_list)
print(string_isalnum)
# Out:
# year2021month09day24

# %% [markdown]
# # [↩️ 리스트로 돌아가기](https://dacon.io/competitions/open/235698/overview/description)
